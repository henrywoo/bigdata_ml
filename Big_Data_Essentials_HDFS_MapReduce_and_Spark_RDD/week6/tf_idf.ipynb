# %%
# %%writefile mapper_dt.py


import sys
import re


reload(sys)
sys.setdefaultencoding('utf-8')  # required to convert to unicode

# the word we search
searched_word = 'labor'

docs_with_word = 0

# let's read articles... One article per line, starting with id
for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
        article_id = int(article_id)
    except ValueError as e:
        print e
        continue

    # split words
    words_with_sws = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    # to lower case
    words_with_sws = [x.lower() for x in words_with_sws]

    if searched_word in words_with_sws:
        print "0\t1"
# Out:
# Writing mapper_dt.py

# %%
# %%writefile reducer_dt.py

import sys

current_key = None
word_sum = 0

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key:
            print "%s\t%d" % (current_key, word_sum)
        word_sum = 0
        current_key = key
    word_sum += count

if current_key:
    print "%s\t%d" % (current_key, word_sum)
# Out:
# Writing reducer_dt.py

# %%
# %%bash
#
# OUT_DIR_DT=dt_dir
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_DT} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="TF IDF" \
#     -files mapper_dt.py,reducer_dt.py \
#     -mapper "python mapper_dt.py" \
#     -reducer "python reducer_dt.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR_DT} > /dev/null
#
# # output result to console
# hdfs dfs -cat ${OUT_DIR_DT}/part-* | grep -P '^0\t' | cut -f 2 > Dt.txt
# Out:
# rm: `dt_dir': No such file or directory
# 19/02/11 02:53:07 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/02/11 02:53:07 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/02/11 02:53:08 INFO mapred.FileInputFormat: Total input files to process : 1
# 19/02/11 02:53:09 INFO mapreduce.JobSubmitter: number of splits:2
# 19/02/11 02:53:10 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1549848047368_0012
# 19/02/11 02:53:10 INFO impl.YarnClientImpl: Submitted application application_1549848047368_0012
# 19/02/11 02:53:10 INFO mapreduce.Job: The url to track the job: http://77d7191c477d:8088/proxy/application_1549848047368_0012/
# 19/02/11 02:53:10 INFO mapreduce.Job: Running job: job_1549848047368_0012
# 19/02/11 02:53:16 INFO mapreduce.Job: Job job_1549848047368_0012 running in uber mode : false
# 19/02/11 02:53:16 INFO mapreduce.Job:  map 0% reduce 0%
# 19/02/11 02:53:26 INFO mapreduce.Job:  map 100% reduce 0%
# 19/02/11 02:53:30 INFO mapreduce.Job:  map 100% reduce 100%
# 19/02/11 02:53:32 INFO mapreduce.Job: Job job_1549848047368_0012 completed successfully
# 19/02/11 02:53:32 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=1650
# 		FILE: Number of bytes written=422198
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=6
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=15550
# 		Total time spent by all reduces in occupied slots (ms)=2350
# 		Total time spent by all map tasks (ms)=15550
# 		Total time spent by all reduce tasks (ms)=2350
# 		Total vcore-milliseconds taken by all map tasks=15550
# 		Total vcore-milliseconds taken by all reduce tasks=2350
# 		Total megabyte-milliseconds taken by all map tasks=15923200
# 		Total megabyte-milliseconds taken by all reduce tasks=2406400
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=274
# 		Map output bytes=1096
# 		Map output materialized bytes=1656
# 		Input split bytes=228
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1
# 		Reduce shuffle bytes=1656
# 		Reduce input records=274
# 		Reduce output records=1
# 		Spilled Records=548
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=196
# 		CPU time spent (ms)=3060
# 		Physical memory (bytes) snapshot=750530560
# 		Virtual memory (bytes) snapshot=6033358848
# 		Total committed heap usage (bytes)=548405248
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=6
# 19/02/11 02:53:32 INFO streaming.StreamJob: Output directory: dt_dir

# %%
# %%writefile m.py


import sys
import re
import math


reload(sys)
sys.setdefaultencoding('utf-8')  # required to convert to unicode

# stop words
swf = open('stop_words_en.txt', 'r')
sws = swf.read().split('\n')
swf.close()

dtf = open('Dt.txt')
Dt = dtf.read()
Dt = float(Dt)

idf = float(1)/math.log(1+Dt)

# the word we search
searched_word = 'labor'
# the article for which we compute TF IDF
lookedup_article = 12

docs_with_word = 0

# let's read articles... One article per line, starting with id
for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
        article_id = int(article_id)
    except ValueError as e:
        print e
        continue

    # split words
    words_with_sws = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    # to lower case
    words_with_sws = [x.lower() for x in words_with_sws]
    # without stop words
    words = [x for x in words_with_sws if x not in sws]
    searched_word_count = words.count(searched_word)
    word_count = len(words)

    # we look for the tf idf for article 12
    # so, lets ouput these values only for this article...
    if article_id == lookedup_article:
        tf_idf = (float(searched_word_count)/float(word_count))*idf
        print "%s\t%s\t%s\t%g" % (article_id, searched_word_count, word_count,tf_idf)
# Out:
# Writing mapper.py

# %%
# %%bash
#
# OUT_DIR="coursera_mr_task"$(date +"%s%6N")
# NUM_MAPPERS=8
#
# # Stub code for your job
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="TF IDF" \
#     -D mapreduce.job.reduces=0 \
#     -D mapred.job.maps=${NUM_MAPPERS} \
#     -files m.py,/datasets/stop_words_en.txt,Dt.txt \
#     -mapper "python m.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR} > /dev/null
#
# # output result to console
# hdfs dfs -cat ${OUT_DIR}/part-* | grep -P '^12\t' | cut -f 4
# Out:
# 0.000350469
# 19/02/11 02:53:42 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/02/11 02:53:42 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/02/11 02:53:44 INFO mapred.FileInputFormat: Total input files to process : 1
# 19/02/11 02:53:44 INFO mapreduce.JobSubmitter: number of splits:2
# 19/02/11 02:53:44 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1549848047368_0013
# 19/02/11 02:53:44 INFO impl.YarnClientImpl: Submitted application application_1549848047368_0013
# 19/02/11 02:53:44 INFO mapreduce.Job: The url to track the job: http://77d7191c477d:8088/proxy/application_1549848047368_0013/
# 19/02/11 02:53:44 INFO mapreduce.Job: Running job: job_1549848047368_0013
# 19/02/11 02:53:50 INFO mapreduce.Job: Job job_1549848047368_0013 running in uber mode : false
# 19/02/11 02:53:50 INFO mapreduce.Job:  map 0% reduce 0%
# 19/02/11 02:54:06 INFO mapreduce.Job:  map 8% reduce 0%
# 19/02/11 02:54:12 INFO mapreduce.Job:  map 12% reduce 0%
# 19/02/11 02:54:18 INFO mapreduce.Job:  map 16% reduce 0%
# 19/02/11 02:54:24 INFO mapreduce.Job:  map 20% reduce 0%
# 19/02/11 02:54:30 INFO mapreduce.Job:  map 24% reduce 0%
# 19/02/11 02:54:37 INFO mapreduce.Job:  map 28% reduce 0%
# 19/02/11 02:54:43 INFO mapreduce.Job:  map 32% reduce 0%
# 19/02/11 02:54:49 INFO mapreduce.Job:  map 36% reduce 0%
# 19/02/11 02:54:55 INFO mapreduce.Job:  map 40% reduce 0%
# 19/02/11 02:55:01 INFO mapreduce.Job:  map 44% reduce 0%
# 19/02/11 02:55:07 INFO mapreduce.Job:  map 48% reduce 0%
# 19/02/11 02:55:13 INFO mapreduce.Job:  map 52% reduce 0%
# 19/02/11 02:55:19 INFO mapreduce.Job:  map 56% reduce 0%
# 19/02/11 02:55:25 INFO mapreduce.Job:  map 60% reduce 0%
# 19/02/11 02:55:31 INFO mapreduce.Job:  map 64% reduce 0%
# 19/02/11 02:55:37 INFO mapreduce.Job:  map 69% reduce 0%
# 19/02/11 02:55:43 INFO mapreduce.Job:  map 73% reduce 0%
# 19/02/11 02:55:49 INFO mapreduce.Job:  map 76% reduce 0%
# 19/02/11 02:55:55 INFO mapreduce.Job:  map 81% reduce 0%
# 19/02/11 02:56:01 INFO mapreduce.Job:  map 85% reduce 0%
# 19/02/11 02:56:07 INFO mapreduce.Job:  map 89% reduce 0%
# 19/02/11 02:56:13 INFO mapreduce.Job:  map 93% reduce 0%
# 19/02/11 02:56:19 INFO mapreduce.Job:  map 97% reduce 0%
# 19/02/11 02:56:25 INFO mapreduce.Job:  map 99% reduce 0%
# 19/02/11 02:56:27 INFO mapreduce.Job:  map 100% reduce 0%
# 19/02/11 02:56:29 INFO mapreduce.Job: Job job_1549848047368_0013 completed successfully
# 19/02/11 02:56:29 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=0
# 		FILE: Number of bytes written=279422
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=23
# 		HDFS: Number of read operations=10
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=4
# 	Job Counters
# 		Launched map tasks=2
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=303540
# 		Total time spent by all reduces in occupied slots (ms)=0
# 		Total time spent by all map tasks (ms)=303540
# 		Total vcore-milliseconds taken by all map tasks=303540
# 		Total megabyte-milliseconds taken by all map tasks=310824960
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=1
# 		Input split bytes=228
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=127
# 		CPU time spent (ms)=297450
# 		Physical memory (bytes) snapshot=358129664
# 		Virtual memory (bytes) snapshot=4021886976
# 		Total committed heap usage (bytes)=300417024
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=23
# 19/02/11 02:56:29 INFO streaming.StreamJob: Output directory: coursera_mr_task1549853620942817
